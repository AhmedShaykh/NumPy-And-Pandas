# %%
import pandas as pd;

studentsData = [
    {"Roll No": 1, "Name": "Alice", "Father Name": "Bob", "Course": "Physics", "Date Of Admission": "2023-01-10", "Fee": 10000},
    {"Roll No": 2, "Name": "Brian", "Father Name": "Steve", "Course": "Chemistry", "Date Of Admission": "2023-02-12", "Fee": 11000},
    {"Roll No": 3, "Name": "Chloe", "Father Name": "Tim", "Course": "Biology", "Date Of Admission": "2023-03-14", "Fee": 12000},
    {"Roll No": 4, "Name": "David", "Father Name": "Rick", "Course": "Mathematics", "Date Of Admission": "2023-04-10", "Fee": 13000},
    {"Roll No": 5, "Name": "Eva", "Father Name": "John", "Course": "Computer Science", "Date Of Admission": "2023-11-16", "Fee": 14000},
    {"Roll No": 6, "Name": "Frank", "Father Name": "Tom", "Course": "Economics", "Date Of Admission": "2023-06-21", "Fee": 15000},
    {"Roll No": 7, "Name": "Grace", "Father Name": "Harry", "Course": "History", "Date Of Admission": "2023-07-25", "Fee": 16000},
    {"Roll No": 8, "Name": "Henry", "Father Name": "Charles", "Course": "Geography", "Date Of Admission": "2023-08-17", "Fee": 17000},
    {"Roll No": 9, "Name": "Isabel", "Father Name": "Oliver", "Course": "English", "Date Of Admission": "2023-09-10", "Fee": 18000},
    {"Roll No": 10, "Name": "Jack", "Father Name": "Noah", "Course": "Art", "Date Of Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf
# Out:
#    Roll No    Name Father Name            Course Date Of Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim           Biology        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom         Economics        2023-06-21  15000
# 6        7   Grace       Harry           History        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah               Art        2023-10-05  19000

# %%
studentsDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Roll No            10 non-null     int64
#  1   Name               10 non-null     object
#  2   Father Name        10 non-null     object
#  3   Course             10 non-null     object
#  4   Date Of Admission  10 non-null     object
#  5   Fee                10 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 608.0+ bytes

# %%
studentsData = [
    {"Roll No": 1, "Name": "Alice", "Father Name": "Bob", "Course": "Physics", "Date Of Admission": "2023-01-10", "Fee": 10000},
    {"Roll No": 2, "Name": "Brian", "Father Name": "Steve", "Course": "Chemistry", "Date Of Admission": "2023-02-12", "Fee": 11000},
    {"Roll No": 3, "Name": "Chloe", "Father Name": "Tim", "Course": "Biology", "Date Of Admission": "2023-03-14", "Fee": 12000},
    {"Roll No": 4, "Name": "David", "Father Name": "Rick", "Course": "Mathematics", "Date Of Admission": "2023-04-10", "Fee": 13000},
    {"Roll No": 5, "Name": "Eva", "Father Name": "John", "Course": "Computer Science", "Date Of Admission": "2023-11-16", "Fee": 14000},
    {"Roll No": 6, "Name": "Frank", "Father Name": "Tom", "Course": "Economics", "Date Of Admission": "2023-06-21", "Fee": 15000},
    {"Roll No": 7, "Name": "Grace", "Father Name": "Harry", "Course": "History", "Date Of Admission": "2023-07-25", "Fee": 16000},
    {"Roll No": 8, "Name": "Henry", "Father Name": "Charles", "Course": "Geography", "Date Of Admission": "2023-08-17", "Fee": 17000},
    {"Roll No": 9, "Name": "Isabel", "Father Name": "Oliver", "Course": "English", "Date Of Admission": "2023-09-10", "Fee": 18000},
    {"Roll No": 10, "Name": "Jack", "Father Name": "Noah", "Course": "Art", "Date Of Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date Of Admission"] = pd.to_datetime(studentsDf["Date Of Admission"]); # Convert String Type To DateTime Type

studentsDf
# Out:
#    Roll No    Name Father Name            Course Date Of Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim           Biology        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom         Economics        2023-06-21  15000
# 6        7   Grace       Harry           History        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah               Art        2023-10-05  19000

# %%
studentsDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Roll No            10 non-null     int64
#  1   Name               10 non-null     object
#  2   Father Name        10 non-null     object
#  3   Course             10 non-null     object
#  4   Date Of Admission  10 non-null     datetime64[ns]
#  5   Fee                10 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 608.0+ bytes

# %%
import pandera as pa;
from pandera.typing import Series;
from datetime import datetime;

class StudentSchema(pa.SchemaModel):
    Roll_No: Series[int] = pa.Field(ge=1);
    Name: Series[str] = pa.Field(nullable=False);
    Father_Name: Series[str] = pa.Field(nullable=False);
    Course: Series[str] = pa.Field(nullable=False);
    Date_Of_Admission: Series[datetime] = pa.Field(le=datetime.now());
    Fee: Series[int] = pa.Field(ge=0);

studentsData = [
    {"Roll_No": 1, "Name": "Alice", "Father_Name": "Bob", "Course": "Physics", "Date_Of_Admission": "2023-01-10", "Fee": 10000},
    {"Roll_No": 2, "Name": "Brian", "Father_Name": "Steve", "Course": "Chemistry", "Date_Of_Admission": "2023-02-12", "Fee": 11000},
    {"Roll_No": 3, "Name": "Chloe", "Father_Name": "Tim", "Course": "Biology", "Date_Of_Admission": "2023-03-14", "Fee": 12000},
    {"Roll_No": 4, "Name": "David", "Father_Name": "Rick", "Course": "Mathematics", "Date_Of_Admission": "2023-04-10", "Fee": 13000},
    {"Roll_No": 5, "Name": "Eva", "Father_Name": "John", "Course": "Computer Science", "Date_Of_Admission": "2023-11-16", "Fee": 14000},
    {"Roll_No": 6, "Name": "Frank", "Father_Name": "Tom", "Course": "Economics", "Date_Of_Admission": "2023-06-21", "Fee": 15000},
    {"Roll_No": 7, "Name": "Grace", "Father_Name": "Harry", "Course": "History", "Date_Of_Admission": "2023-07-25", "Fee": 16000},
    {"Roll_No": 8, "Name": "Henry", "Father_Name": "Charles", "Course": "Geography", "Date_Of_Admission": "2023-08-17", "Fee": 17000},
    {"Roll_No": 9, "Name": "Isabel", "Father_Name": "Oliver", "Course": "English", "Date_Of_Admission": "2023-09-10", "Fee": 18000},
    {"Roll_No": 10, "Name": "Jack", "Father_Name": "Noah", "Course": "Art", "Date_Of_Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date_Of_Admission"] = pd.to_datetime(studentsDf["Date_Of_Admission"]);

validatedDf = StudentSchema.validate(studentsDf);

validatedDf
# Out:
#    Roll_No    Name Father_Name            Course Date_Of_Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim           Biology        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom         Economics        2023-06-21  15000
# 6        7   Grace       Harry           History        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah               Art        2023-10-05  19000

# %% [markdown]
# # **Filter Functions On Dataframe**

# %%
studentsDf.head()
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 0        1  Alice         Bob           Physics        2023-01-10  10000
# 1        2  Brian       Steve         Chemistry        2023-02-12  11000
# 2        3  Chloe         Tim           Biology        2023-03-14  12000
# 3        4  David        Rick       Mathematics        2023-04-10  13000
# 4        5    Eva        John  Computer Science        2023-11-16  14000

# %%
studentsDf.head(2)
# Out:
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 0        1  Alice         Bob    Physics        2023-01-10  10000
# 1        2  Brian       Steve  Chemistry        2023-02-12  11000

# %%
studentsDf.Course.value_counts()
# Out:
# Physics             1
# Chemistry           1
# Biology             1
# Mathematics         1
# Computer Science    1
# Economics           1
# History             1
# Geography           1
# English             1
# Art                 1
# Name: Course, dtype: int64

# %%
import pandas as pd;

studentsData = [
    {"Roll No": 1, "Name": "Alice", "Father Name": "Bob", "Course": "Physics", "Date Of Admission": "2023-01-10", "Fee": 10000},
    {"Roll No": 2, "Name": "Brian", "Father Name": "Steve", "Course": "Chemistry", "Date Of Admission": "2023-02-12", "Fee": 11000},
    {"Roll No": 3, "Name": "Chloe", "Father Name": "Tim", "Course": "Computer Science", "Date Of Admission": "2023-03-14", "Fee": 12000},
    {"Roll No": 4, "Name": "David", "Father Name": "Rick", "Course": "Mathematics", "Date Of Admission": "2023-04-10", "Fee": 13000},
    {"Roll No": 5, "Name": "Eva", "Father Name": "John", "Course": "Computer Science", "Date Of Admission": "2023-11-16", "Fee": 14000},
    {"Roll No": 6, "Name": "Frank", "Father Name": "Tom", "Course": "Computer Science", "Date Of Admission": "2023-06-21", "Fee": 15000},
    {"Roll No": 7, "Name": "Grace", "Father Name": "Harry", "Course": "English", "Date Of Admission": "2023-07-25", "Fee": 16000},
    {"Roll No": 8, "Name": "Henry", "Father Name": "Charles", "Course": "Geography", "Date Of Admission": "2023-08-17", "Fee": 17000},
    {"Roll No": 9, "Name": "Isabel", "Father Name": "Oliver", "Course": "English", "Date Of Admission": "2023-09-10", "Fee": 18000},
    {"Roll No": 10, "Name": "Jack", "Father Name": "Noah", "Course": "Mathematics", "Date Of Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date Of Admission"] = pd.to_datetime(studentsDf["Date Of Admission"]);

studentsDf.Course.value_counts()
# Out:
# Computer Science    3
# Mathematics         2
# English             2
# Physics             1
# Chemistry           1
# Geography           1
# Name: Course, dtype: int64

# %%
studentsDf.Course.value_counts(dropna=False) # Also Counts Null Cell Value
# Out:
# Computer Science    3
# Mathematics         2
# English             2
# Physics             1
# Chemistry           1
# Geography           1
# Name: Course, dtype: int64

# %%
studentsDf.Course.value_counts(dropna=False, normalize=True) # Return In Percentage Of Count Value
# Out:
# Computer Science    0.3
# Mathematics         0.2
# English             0.2
# Physics             0.1
# Chemistry           0.1
# Geography           0.1
# Name: Course, dtype: float64

# %%
studentsDf.Course.value_counts(dropna=False, normalize=True) * 100
# Out:
# Computer Science    30.0
# Mathematics         20.0
# English             20.0
# Physics             10.0
# Chemistry           10.0
# Geography           10.0
# Name: Course, dtype: float64

# %%
studentsDf
# Out:
#    Roll No    Name Father Name            Course Date Of Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim  Computer Science        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom  Computer Science        2023-06-21  15000
# 6        7   Grace       Harry           English        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah       Mathematics        2023-10-05  19000

# %%
import pandas as pd;
import numpy as np;
from datetime import datetime, timedelta;

np.random.seed(0);

transactionsNums = 1000;

currentYear = datetime.now().year;

startDate = datetime(currentYear, 1, 1);

currentDate = datetime.now();

randomDates = [startDate + timedelta(days=np.random.randint(0, (currentDate - startDate).days))
                  for _ in range(transactionsNums)];

randomFees = np.random.randint(low=1, high=5000, size=transactionsNums);

transactionsFees = pd.DataFrame({
    "Date": randomDates,
    "Fees": randomFees
});

transactionsFees.sort_values("Date", inplace=True);

transactionsFees.reset_index(drop=True, inplace=True);

transactionsFees
# Out:
#           Date  Fees
# 0   2023-01-01   491
# 1   2023-01-01  2200
# 2   2023-01-01  4159
# 3   2023-01-01  1125
# 4   2023-01-03  1125
# ..         ...   ...
# 995 2023-12-16  4561
# 996 2023-12-16  2169
# 997 2023-12-16  3314
# 998 2023-12-17  4690
# 999 2023-12-18  4472
#
# [1000 rows x 2 columns]

# %%
pd.cut(transactionsFees.Fees, [1,500,1000,3000,4000,5000]) # Check Categories Of Values
# Out:
# 0          (1, 500]
# 1      (1000, 3000]
# 2      (4000, 5000]
# 3      (1000, 3000]
# 4      (1000, 3000]
#            ...
# 995    (4000, 5000]
# 996    (1000, 3000]
# 997    (3000, 4000]
# 998    (4000, 5000]
# 999    (4000, 5000]
# Name: Fees, Length: 1000, dtype: category
# Categories (5, interval[int64, right]): [(1, 500] < (500, 1000] < (1000, 3000] < (3000, 4000] <
#                                          (4000, 5000]]

# %%
pd.cut(transactionsFees.Fees, [1,500,1000,3000,4000,5000]).value_counts()
# Out:
# (1000, 3000]    429
# (3000, 4000]    201
# (4000, 5000]    185
# (1, 500]        106
# (500, 1000]      79
# Name: Fees, dtype: int64

# %%
pd.cut(transactionsFees.Fees, [1,500,1000,3000,4000,5000]).value_counts(normalize=True) * 100
# Out:
# (1000, 3000]    42.9
# (3000, 4000]    20.1
# (4000, 5000]    18.5
# (1, 500]        10.6
# (500, 1000]      7.9
# Name: Fees, dtype: float64

# %%
pd.qcut(transactionsFees.Fees,[0, 0.3, 0.5, 0.7, 0.9, 1]) # Percentile
# Out:
# 0      (19.999, 1530.2]
# 1      (1530.2, 2397.5]
# 2      (3480.5, 4439.2]
# 3      (19.999, 1530.2]
# 4      (19.999, 1530.2]
#              ...
# 995    (4439.2, 4998.0]
# 996    (1530.2, 2397.5]
# 997    (2397.5, 3480.5]
# 998    (4439.2, 4998.0]
# 999    (4439.2, 4998.0]
# Name: Fees, Length: 1000, dtype: category
# Categories (5, interval[float64, right]): [(19.999, 1530.2] < (1530.2, 2397.5] < (2397.5, 3480.5] <
#                                            (3480.5, 4439.2] < (4439.2, 4998.0]]

# %%
pd.qcut(transactionsFees.Fees,[0, 0.3, 0.5, 0.7, 0.9, 1]).value_counts()
# Out:
# (19.999, 1530.2]    300
# (1530.2, 2397.5]    200
# (2397.5, 3480.5]    200
# (3480.5, 4439.2]    200
# (4439.2, 4998.0]    100
# Name: Fees, dtype: int64

# %%
pd.qcut(transactionsFees.Fees,[0, 0.3, 0.5, 0.7, 0.9, 1]).value_counts(normalize=True) * 100
# Out:
# (19.999, 1530.2]    30.0
# (1530.2, 2397.5]    20.0
# (2397.5, 3480.5]    20.0
# (3480.5, 4439.2]    20.0
# (4439.2, 4998.0]    10.0
# Name: Fees, dtype: float64

# %%
studentsDf.head()
# Out:
#    Roll No   Name Father Name            Course Date Of Admission    Fee
# 0        1  Alice         Bob           Physics        2023-01-10  10000
# 1        2  Brian       Steve         Chemistry        2023-02-12  11000
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 3        4  David        Rick       Mathematics        2023-04-10  13000
# 4        5    Eva        John  Computer Science        2023-11-16  14000

# %% [markdown]
# # **Filter On Columns**

# %%
import pandera as pa;
from pandera.typing import Series;
from datetime import datetime;

class StudentSchema(pa.SchemaModel):
    Roll_No: Series[int] = pa.Field(ge=1);
    Name: Series[str] = pa.Field(nullable=False);
    Father_Name: Series[str] = pa.Field(nullable=False);
    Course: Series[str] = pa.Field(nullable=False);
    Date_Of_Admission: Series[datetime] = pa.Field(le=datetime.now());
    Fee: Series[int] = pa.Field(ge=0);

studentsData = [
    {"Roll_No": 1, "Name": "Alice", "Father_Name": "Bob", "Course": "Physics", "Date_Of_Admission": "2023-01-10", "Fee": 10000},
    {"Roll_No": 2, "Name": "Brian", "Father_Name": "Steve", "Course": "Chemistry", "Date_Of_Admission": "2023-02-12", "Fee": 11000},
    {"Roll_No": 3, "Name": "Chloe", "Father_Name": "Tim", "Course": "Computer Science", "Date_Of_Admission": "2023-03-14", "Fee": 12000},
    {"Roll_No": 4, "Name": "David", "Father_Name": "Rick", "Course": "Mathematics", "Date_Of_Admission": "2023-04-10", "Fee": 13000},
    {"Roll_No": 5, "Name": "Eva", "Father_Name": "John", "Course": "Computer Science", "Date_Of_Admission": "2023-11-16", "Fee": 14000},
    {"Roll_No": 6, "Name": "Frank", "Father_Name": "Tom", "Course": "Computer Science", "Date_Of_Admission": "2023-06-21", "Fee": 15000},
    {"Roll_No": 7, "Name": "Grace", "Father_Name": "Harry", "Course": "English", "Date_Of_Admission": "2023-07-25", "Fee": 16000},
    {"Roll_No": 8, "Name": "Henry", "Father_Name": "Charles", "Course": "Geography", "Date_Of_Admission": "2023-08-17", "Fee": 17000},
    {"Roll_No": 9, "Name": "Isabel", "Father_Name": "Oliver", "Course": "English", "Date_Of_Admission": "2023-09-10", "Fee": 18000},
    {"Roll_No": 10, "Name": "Jack", "Father_Name": "Noah", "Course": "Mathematics", "Date_Of_Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date_Of_Admission"] = pd.to_datetime(studentsDf["Date_Of_Admission"]);

validatedDf = StudentSchema.validate(studentsDf);

validatedDf
# Out:
#    Roll_No    Name Father_Name            Course Date_Of_Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim  Computer Science        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom  Computer Science        2023-06-21  15000
# 6        7   Grace       Harry           English        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah       Mathematics        2023-10-05  19000

# %%
studentsDf["Course"]
# Out:
# 0             Physics
# 1           Chemistry
# 2    Computer Science
# 3         Mathematics
# 4    Computer Science
# 5    Computer Science
# 6             English
# 7           Geography
# 8             English
# 9         Mathematics
# Name: Course, dtype: object

# %%
studentsDf["Course"] == "Computer Science"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Course, dtype: bool

# %%
studentsDf[studentsDf["Course"] == "Computer Science"] # Boolean Slicing
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000

# %%
studentsDf["Course"].str.lower() == "computer science"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Course, dtype: bool

# %%
studentsDf[studentsDf["Course"].str.lower() == "computer science"]
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000

# %%
studentsDf["Course"].str.lower().str.contains("comp")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Course, dtype: bool

# %%
studentsDf[studentsDf["Course"].str.lower().str.contains("comp")]
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000

# %%
studentsDf[(studentsDf["Course"].str.lower().str.contains("comp")) & (studentsDf["Fee"] >= 14000)]
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000

# %%
studentsDf["Course"].str.lower().str.contains("comp") & studentsDf["Course"].str.lower().str.contains("r") # Check Same Values In Both Condition
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Course, dtype: bool

# %%
studentsDf[studentsDf["Course"].str.lower().str.contains("comp") & studentsDf["Course"].str.lower().str.contains("r")]
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000

# %%
studentsDf["Course"].str.lower().str.contains("comp") | studentsDf["Course"].str.lower().str.contains("r")
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Course, dtype: bool

# %%
studentsDf[studentsDf["Course"].str.lower().str.contains("comp") | studentsDf["Course"].str.lower().str.contains("r")]
# Out:
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 1        2  Brian       Steve         Chemistry        2023-02-12  11000
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000
# 7        8  Henry     Charles         Geography        2023-08-17  17000

# %%
import pandera as pa;
from pandera.typing import Series;
from datetime import datetime;

class StudentSchema(pa.SchemaModel):
    Roll_No: Series[int] = pa.Field(ge=1);
    Name: Series[str] = pa.Field(nullable=False);
    Father_Name: Series[str] = pa.Field(nullable=False);
    Course: Series[str] = pa.Field(nullable=False);
    Date_Of_Admission: Series[datetime] = pa.Field(le=datetime.now());
    Fee: Series[int] = pa.Field(ge=0);

studentsData = [
    {"Roll_No": 1, "Name": "Alice", "Father_Name": "Bob", "Course": "Physics", "Date_Of_Admission": "2023-01-10", "Fee": 10000},
    {"Roll_No": 2, "Name": "Brian", "Father_Name": "Steve", "Course": "Chemistry", "Date_Of_Admission": "2023-02-12", "Fee": 11000},
    {"Roll_No": 3, "Name": "Chloe", "Father_Name": "Tim", "Course": "Computer Science", "Date_Of_Admission": "2023-03-14", "Fee": 12000},
    {"Roll_No": 4, "Name": "David", "Father_Name": "Rick", "Course": "Mathematics", "Date_Of_Admission": "2023-04-10", "Fee": 13000},
    {"Roll_No": 5, "Name": "Eva", "Father_Name": "John", "Course": "Computer Science", "Date_Of_Admission": "2023-11-16", "Fee": 14000},
    {"Roll_No": 6, "Name": "Frank", "Father_Name": "Tom", "Course": "Computer Science", "Date_Of_Admission": "2023-06-21", "Fee": 15000},
    {"Roll_No": 7, "Name": "Grace", "Father_Name": "Harry", "Course": "English", "Date_Of_Admission": "2023-07-25", "Fee": 16000},
    {"Roll_No": 8, "Name": "Henry", "Father_Name": "Charles", "Course": "Geography", "Date_Of_Admission": "2023-08-17", "Fee": 17000},
    {"Roll_No": 9, "Name": "Isabel", "Father_Name": "Oliver", "Course": "English", "Date_Of_Admission": "2023-09-10", "Fee": 18000},
    {"Roll_No": 10, "Name": "Jack", "Father_Name": "Noah", "Course": "Mathematics", "Date_Of_Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date_Of_Admission"] = pd.to_datetime(studentsDf["Date_Of_Admission"]);

validatedDf = StudentSchema.validate(studentsDf);

validatedDf
# Out:
#    Roll_No    Name Father_Name            Course Date_Of_Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim  Computer Science        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom  Computer Science        2023-06-21  15000
# 6        7   Grace       Harry           English        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah       Mathematics        2023-10-05  19000

# %% [markdown]
# # **Filter On Date Column**
#
# ### **DateTime Symbols**
#
# - `%a` - Abbreviated weekday name.
# - `%A` - Full weekday name.
# - `%w` - Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.
# - `%d` - Day of the month as a zero-padded decimal number.
# - `%b` - Abbreviated month name.
# - `%B` - Full month name.
# - `%m` - Month as a zero-padded decimal number.
# - `%y` - Year without century as a zero-padded decimal number.
# - `%Y` - Year with century as a decimal number.
# - `%H` - Hour (24-hour clock) as a zero-padded decimal number.
# - `%I` - Hour (12-hour clock) as a zero-padded decimal number.
# - `%p` - Locale’s equivalent of either AM or PM.
# - `%M` - Minute as a zero-padded decimal number.
# - `%S` - Second as a zero-padded decimal number.
# - `%f` - Microsecond as a decimal number, zero-padded on the left.
# - `%z` - UTC offset in the form ±HHMM[SS[.ffffff]] (empty string if the object is naive).
# - `%Z` - Time zone name (empty string if the object is naive).
# - `%j` - Day of the year as a zero-padded decimal number.
# - `%U` - Week number of the year (Sunday as the first day of the week) as a zero-padded decimal number.
# - `%W` - Week number of the year (Monday as the first day of the week) as a zero-padded decimal number.
# - `%c` - Locale’s appropriate date and time representation.
# - `%x` - Locale’s appropriate date representation.
# - `%X` - Locale’s appropriate time representation.
# - `%G` - ISO 8601 year with century representing the year that contains the greater part of the ISO week (`%V`).
# - `%u` - ISO 8601 weekday as a decimal number where 1 is Monday.
# - `%V` - ISO 8601 week number as a decimal number with Monday as the first day of the week.

# %%
studentsDf["Date_Of_Admission"]
# Out:
# 0   2023-01-10
# 1   2023-02-12
# 2   2023-03-14
# 3   2023-04-10
# 4   2023-11-16
# 5   2023-06-21
# 6   2023-07-25
# 7   2023-08-17
# 8   2023-09-10
# 9   2023-10-05
# Name: Date_Of_Admission, dtype: datetime64[ns]

# %%
studentsDf["Date_Of_Admission"].dt.year # All Data In Pandas3.py File

studentsDf["Date_Of_Admission"].dt.month

studentsDf["Date_Of_Admission"].dt.day

studentsDf["Date_Of_Admission"].dt.weekday

studentsDf["Date_Of_Admission"].dt.day_of_week

studentsDf["Date_Of_Admission"].dt.hour

studentsDf["Date_Of_Admission"].dt.minute

studentsDf["Date_Of_Admission"].dt.second

studentsDf["Date_Of_Admission"].dt.microsecond

studentsDf["Date_Of_Admission"].dt.tz # Time Zone

studentsDf["Date_Of_Admission"].dt.tz_localize

studentsDf["Date_Of_Admission"].dt.tz_convert

studentsDf["Date_Of_Admission"].dt.tz_localize(None)
# Out:
# 0   2023-01-10
# 1   2023-02-12
# 2   2023-03-14
# 3   2023-04-10
# 4   2023-11-16
# 5   2023-06-21
# 6   2023-07-25
# 7   2023-08-17
# 8   2023-09-10
# 9   2023-10-05
# Name: Date_Of_Admission, dtype: datetime64[ns]

# %%
dir(studentsDf["Date_Of_Admission"].dt)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_add_delegate_accessors',
#  '_constructor',
#  '_delegate_method',
#  '_delegate_property_get',
#  '_delegate_property_set',
#  '_dir_additions',
#  '_dir_deletions',
#  '_freeze',
#  '_get_values',
#  '_hidden_attrs',
#  '_parent',
#  '_reset_cache',
#  'ceil',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'floor',
#  'freq',
#  'hour',
#  'is_leap_year',
#  'is_month_end',
#  'is_month_start',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_year_end',
#  'is_year_start',
#  'isocalendar',
#  'microsecond',
#  'minute',
#  'month',
#  'month_name',
#  'nanosecond',
#  'normalize',
#  'quarter',
#  'round',
#  'second',
#  'strftime',
#  'time',
#  'timetz',
#  'to_period',
#  'to_pydatetime',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
[i for i in dir(studentsDf["Date_Of_Admission"].dt) if "_" not in i]
# Out:
# ['ceil',
#  'date',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'daysinmonth',
#  'floor',
#  'freq',
#  'hour',
#  'isocalendar',
#  'microsecond',
#  'minute',
#  'month',
#  'nanosecond',
#  'normalize',
#  'quarter',
#  'round',
#  'second',
#  'strftime',
#  'time',
#  'timetz',
#  'tz',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
from datetime import datetime;

date : datetime = datetime.now();

date
# Out:
# datetime.datetime(2023, 12, 19, 20, 43, 27, 82208)

# %%
s1 : pd.Series = pd.Series([date]);

s1
# Out:
# 0   2023-12-19 20:43:27.082208
# dtype: datetime64[ns]

# %%
s1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1 entries, 0 to 0
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 136.0 bytes

# %%
s1.dt.strftime("%Y/%m/%d, %I Hours %M Mins %S Sec %f Milli") # Convet From Date To String
# Out:
# 0    2023/12/19, 08 Hours 43 Mins 27 Sec 082208 Milli
# dtype: object

# %%
s2 :pd.Series = pd.Series(["01 Nov 2023", "01 Nov 2024", "01 Nov 2025"]);

s2
# Out:
# 0    01 Nov 2023
# 1    01 Nov 2024
# 2    01 Nov 2025
# dtype: object

# %%
s2.apply(lambda x: datetime.strptime(x,"%d %b %Y")) # Convet From String To Date
# Out:
# 0   2023-11-01
# 1   2024-11-01
# 2   2025-11-01
# dtype: datetime64[ns]

# %% [markdown]
# # **Group By**

# %%
import pandera as pa;
import pandas as pd;
from pandera.typing import Series;
from datetime import datetime;

class StudentSchema(pa.SchemaModel):
    Roll_No: Series[int] = pa.Field(ge=1);
    Name: Series[str] = pa.Field(nullable=False);
    Father_Name: Series[str] = pa.Field(nullable=False);
    Course: Series[str] = pa.Field(nullable=False);
    Date_Of_Admission: Series[datetime] = pa.Field(le=datetime.now());
    Fee: Series[int] = pa.Field(ge=0);

studentsData = [
    {"Roll_No": 1, "Name": "Alice", "Father_Name": "Bob", "Course": "Physics", "Date_Of_Admission": "2023-01-10", "Fee": 10000},
    {"Roll_No": 2, "Name": "Brian", "Father_Name": "Steve", "Course": "Chemistry", "Date_Of_Admission": "2023-02-12", "Fee": 11000},
    {"Roll_No": 3, "Name": "Chloe", "Father_Name": "Tim", "Course": "Computer Science", "Date_Of_Admission": "2023-03-14", "Fee": 12000},
    {"Roll_No": 4, "Name": "David", "Father_Name": "Rick", "Course": "Mathematics", "Date_Of_Admission": "2023-04-10", "Fee": 13000},
    {"Roll_No": 5, "Name": "Eva", "Father_Name": "John", "Course": "Computer Science", "Date_Of_Admission": "2023-11-16", "Fee": 14000},
    {"Roll_No": 6, "Name": "Frank", "Father_Name": "Tom", "Course": "Computer Science", "Date_Of_Admission": "2023-06-21", "Fee": 15000},
    {"Roll_No": 7, "Name": "Grace", "Father_Name": "Harry", "Course": "English", "Date_Of_Admission": "2023-07-25", "Fee": 16000},
    {"Roll_No": 8, "Name": "Henry", "Father_Name": "Charles", "Course": "Geography", "Date_Of_Admission": "2023-08-17", "Fee": 17000},
    {"Roll_No": 9, "Name": "Isabel", "Father_Name": "Oliver", "Course": "English", "Date_Of_Admission": "2023-09-10", "Fee": 18000},
    {"Roll_No": 10, "Name": "Jack", "Father_Name": "Noah", "Course": "Mathematics", "Date_Of_Admission": "2023-10-05", "Fee": 19000}
];

studentsDf : pd.DataFrame = pd.DataFrame(studentsData);

studentsDf["Date_Of_Admission"] = pd.to_datetime(studentsDf["Date_Of_Admission"]);

validatedDf = StudentSchema.validate(studentsDf);

validatedDf
# Out:
#    Roll_No    Name Father_Name            Course Date_Of_Admission    Fee
# 0        1   Alice         Bob           Physics        2023-01-10  10000
# 1        2   Brian       Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe         Tim  Computer Science        2023-03-14  12000
# 3        4   David        Rick       Mathematics        2023-04-10  13000
# 4        5     Eva        John  Computer Science        2023-11-16  14000
# 5        6   Frank         Tom  Computer Science        2023-06-21  15000
# 6        7   Grace       Harry           English        2023-07-25  16000
# 7        8   Henry     Charles         Geography        2023-08-17  17000
# 8        9  Isabel      Oliver           English        2023-09-10  18000
# 9       10    Jack        Noah       Mathematics        2023-10-05  19000

# %%
studentsDf.groupby(("Course"))

# %%
list(studentsDf.groupby("Course"))
# Out:
# [('Chemistry',
#      Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
#   1        2  Brian       Steve  Chemistry        2023-02-12  11000),
#  ('Computer Science',
#      Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
#   2        3  Chloe         Tim  Computer Science        2023-03-14  12000
#   4        5    Eva        John  Computer Science        2023-11-16  14000
#   5        6  Frank         Tom  Computer Science        2023-06-21  15000),
#  ('English',
#      Roll_No    Name Father_Name   Course Date_Of_Admission    Fee
#   6        7   Grace       Harry  English        2023-07-25  16000
#   8        9  Isabel      Oliver  English        2023-09-10  18000),
#  ('Geography',
#      Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
#   7        8  Henry     Charles  Geography        2023-08-17  17000),
#  ('Mathematics',
#      Roll_No   Name Father_Name       Course Date_Of_Admission    Fee
#   3        4  David        Rick  Mathematics        2023-04-10  13000
#   9       10   Jack        Noah  Mathematics        2023-10-05  19000),
#  ('Physics',
#      Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
#   0        1  Alice         Bob  Physics        2023-01-10  10000)]

# %%
list(studentsDf.groupby(("Course")))[0] # Group Index
# Out:
# ('Chemistry',
#     Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
#  1        2  Brian       Steve  Chemistry        2023-02-12  11000)

# %%
list(studentsDf.groupby(("Course")))[0][0] # Group Index & Row
# Out:
# 'Chemistry'

# %%
list(studentsDf.groupby(("Course")))[0][1] # Group Index & Row
# Out:
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 1        2  Brian       Steve  Chemistry        2023-02-12  11000

# %%
for group in list(studentsDf.groupby(("Course"))):

    display(group[0]);

    display(group[1]);

    print("""============================================================== \n""");
# Out:
# 'Chemistry'
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 1        2  Brian       Steve  Chemistry        2023-02-12  11000
# ==============================================================
# 'Computer Science'
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# 4        5    Eva        John  Computer Science        2023-11-16  14000
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000
# ==============================================================
# 'English'
#    Roll_No    Name Father_Name   Course Date_Of_Admission    Fee
# 6        7   Grace       Harry  English        2023-07-25  16000
# 8        9  Isabel      Oliver  English        2023-09-10  18000
# ==============================================================
# 'Geography'
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 7        8  Henry     Charles  Geography        2023-08-17  17000
# ==============================================================
# 'Mathematics'
#    Roll_No   Name Father_Name       Course Date_Of_Admission    Fee
# 3        4  David        Rick  Mathematics        2023-04-10  13000
# 9       10   Jack        Noah  Mathematics        2023-10-05  19000
# ==============================================================
# 'Physics'
#    Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
# 0        1  Alice         Bob  Physics        2023-01-10  10000
# ==============================================================

# %%
list(studentsDf.groupby(((studentsDf["Date_Of_Admission"].dt.strftime("%B")))))
# Out:
# [('April',
#      Roll_No   Name Father_Name       Course Date_Of_Admission    Fee
#   3        4  David        Rick  Mathematics        2023-04-10  13000),
#  ('August',
#      Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
#   7        8  Henry     Charles  Geography        2023-08-17  17000),
#  ('February',
#      Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
#   1        2  Brian       Steve  Chemistry        2023-02-12  11000),
#  ('January',
#      Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
#   0        1  Alice         Bob  Physics        2023-01-10  10000),
#  ('July',
#      Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
#   6        7  Grace       Harry  English        2023-07-25  16000),
#  ('June',
#      Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
#   5        6  Frank         Tom  Computer Science        2023-06-21  15000),
#  ('March',
#      Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
#   2        3  Chloe         Tim  Computer Science        2023-03-14  12000),
#  ('November',
#      Roll_No Name Father_Name            Course Date_Of_Admission    Fee
#   4        5  Eva        John  Computer Science        2023-11-16  14000),
#  ('October',
#      Roll_No  Name Father_Name       Course Date_Of_Admission    Fee
#   9       10  Jack        Noah  Mathematics        2023-10-05  19000),
#  ('September',
#      Roll_No    Name Father_Name   Course Date_Of_Admission    Fee
#   8        9  Isabel      Oliver  English        2023-09-10  18000)]

# %%
for group in list(studentsDf.groupby((studentsDf["Date_Of_Admission"].dt.strftime("%B")))):

    display(group[0]);

    display(group[1]);

    print("""============================================================== \n""");
# Out:
# 'April'
#    Roll_No   Name Father_Name       Course Date_Of_Admission    Fee
# 3        4  David        Rick  Mathematics        2023-04-10  13000
# ==============================================================
# 'August'
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 7        8  Henry     Charles  Geography        2023-08-17  17000
# ==============================================================
# 'February'
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 1        2  Brian       Steve  Chemistry        2023-02-12  11000
# ==============================================================
# 'January'
#    Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
# 0        1  Alice         Bob  Physics        2023-01-10  10000
# ==============================================================
# 'July'
#    Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
# 6        7  Grace       Harry  English        2023-07-25  16000
# ==============================================================
# 'June'
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000
# ==============================================================
# 'March'
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# ==============================================================
# 'November'
#    Roll_No Name Father_Name            Course Date_Of_Admission    Fee
# 4        5  Eva        John  Computer Science        2023-11-16  14000
# ==============================================================
# 'October'
#    Roll_No  Name Father_Name       Course Date_Of_Admission    Fee
# 9       10  Jack        Noah  Mathematics        2023-10-05  19000
# ==============================================================
# 'September'
#    Roll_No    Name Father_Name   Course Date_Of_Admission    Fee
# 8        9  Isabel      Oliver  English        2023-09-10  18000
# ==============================================================

# %%
for group in list(studentsDf.groupby([studentsDf["Date_Of_Admission"].dt.strftime("%B"), studentsDf["Course"]])):

    display(group[0]);

    display(group[1]);

    print("""============================================================== \n""");
# Out:
# ('April', 'Mathematics')
#    Roll_No   Name Father_Name       Course Date_Of_Admission    Fee
# 3        4  David        Rick  Mathematics        2023-04-10  13000
# ==============================================================
# ('August', 'Geography')
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 7        8  Henry     Charles  Geography        2023-08-17  17000
# ==============================================================
# ('February', 'Chemistry')
#    Roll_No   Name Father_Name     Course Date_Of_Admission    Fee
# 1        2  Brian       Steve  Chemistry        2023-02-12  11000
# ==============================================================
# ('January', 'Physics')
#    Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
# 0        1  Alice         Bob  Physics        2023-01-10  10000
# ==============================================================
# ('July', 'English')
#    Roll_No   Name Father_Name   Course Date_Of_Admission    Fee
# 6        7  Grace       Harry  English        2023-07-25  16000
# ==============================================================
# ('June', 'Computer Science')
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 5        6  Frank         Tom  Computer Science        2023-06-21  15000
# ==============================================================
# ('March', 'Computer Science')
#    Roll_No   Name Father_Name            Course Date_Of_Admission    Fee
# 2        3  Chloe         Tim  Computer Science        2023-03-14  12000
# ==============================================================
# ('November', 'Computer Science')
#    Roll_No Name Father_Name            Course Date_Of_Admission    Fee
# 4        5  Eva        John  Computer Science        2023-11-16  14000
# ==============================================================
# ('October', 'Mathematics')
#    Roll_No  Name Father_Name       Course Date_Of_Admission    Fee
# 9       10  Jack        Noah  Mathematics        2023-10-05  19000
# ==============================================================
# ('September', 'English')
#    Roll_No    Name Father_Name   Course Date_Of_Admission    Fee
# 8        9  Isabel      Oliver  English        2023-09-10  18000
# ==============================================================

# %%
studentsDf.groupby(["Course"]).aggregate("count")
# Out:
#                   Roll_No  Name  Father_Name  Date_Of_Admission  Fee
# Course
# Chemistry               1     1            1                  1    1
# Computer Science        3     3            3                  3    3
# English                 2     2            2                  2    2
# Geography               1     1            1                  1    1
# Mathematics             2     2            2                  2    2
# Physics                 1     1            1                  1    1

# %%
studentsDf.groupby(["Course"])[["Fee"]].aggregate("count")
# Out:
#                   Fee
# Course
# Chemistry           1
# Computer Science    3
# English             2
# Geography           1
# Mathematics         2
# Physics             1

# %%
studentsDf.groupby(["Course"])[["Fee"]].agg([len, "min", "max"])
# Out:
#                  Fee
#                  len    min    max
# Course
# Chemistry          1  11000  11000
# Computer Science   3  12000  15000
# English            2  16000  18000
# Geography          1  17000  17000
# Mathematics        2  13000  19000
# Physics            1  10000  10000

# %%
studentsDf.groupby(["Course", studentsDf["Date_Of_Admission"]])[["Fee"]].agg([len, "min", "max"]) # Course Group Add DataFrame Of Date
# Out:
#                                    Fee
#                                    len    min    max
# Course           Date_Of_Admission
# Chemistry        2023-02-12          1  11000  11000
# Computer Science 2023-03-14          1  12000  12000
#                  2023-06-21          1  15000  15000
#                  2023-11-16          1  14000  14000
# English          2023-07-25          1  16000  16000
#                  2023-09-10          1  18000  18000
# Geography        2023-08-17          1  17000  17000
# Mathematics      2023-04-10          1  13000  13000
#                  2023-10-05          1  19000  19000
# Physics          2023-01-10          1  10000  10000

# %%
studentsDf.groupby(["Course", studentsDf["Date_Of_Admission"].dt.strftime("%B")])[["Fee"]].agg([len, "min", "max"])
# Out:
#                                    Fee
#                                    len    min    max
# Course           Date_Of_Admission
# Chemistry        February            1  11000  11000
# Computer Science June                1  15000  15000
#                  March               1  12000  12000
#                  November            1  14000  14000
# English          July                1  16000  16000
#                  September           1  18000  18000
# Geography        August              1  17000  17000
# Mathematics      April               1  13000  13000
#                  October             1  19000  19000
# Physics          January             1  10000  10000

# %%
studentsDf.groupby(("Course"), group_keys=True).apply(lambda x: x.head())
# Out:
#                     Roll_No    Name Father_Name            Course  \
# Course
# Chemistry        1        2   Brian       Steve         Chemistry
# Computer Science 2        3   Chloe         Tim  Computer Science
#                  4        5     Eva        John  Computer Science
#                  5        6   Frank         Tom  Computer Science
# English          6        7   Grace       Harry           English
#                  8        9  Isabel      Oliver           English
# Geography        7        8   Henry     Charles         Geography
# Mathematics      3        4   David        Rick       Mathematics
#                  9       10    Jack        Noah       Mathematics
# Physics          0        1   Alice         Bob           Physics
#
#                    Date_Of_Admission    Fee
# Course
# Chemistry        1        2023-02-12  11000
# Computer Science 2        2023-03-14  12000
#                  4        2023-11-16  14000
#                  5        2023-06-21  15000
# English          6        2023-07-25  16000
#                  8        2023-09-10  18000
# Geography        7        2023-08-17  17000
# Mathematics      3        2023-04-10  13000
#                  9        2023-10-05  19000
# Physics          0        2023-01-10  10000

# %%
studentsDf.groupby(("Course"), group_keys=True).apply(lambda x: x.head(2))
# Out:
#                     Roll_No    Name Father_Name            Course  \
# Course
# Chemistry        1        2   Brian       Steve         Chemistry
# Computer Science 2        3   Chloe         Tim  Computer Science
#                  4        5     Eva        John  Computer Science
# English          6        7   Grace       Harry           English
#                  8        9  Isabel      Oliver           English
# Geography        7        8   Henry     Charles         Geography
# Mathematics      3        4   David        Rick       Mathematics
#                  9       10    Jack        Noah       Mathematics
# Physics          0        1   Alice         Bob           Physics
#
#                    Date_Of_Admission    Fee
# Course
# Chemistry        1        2023-02-12  11000
# Computer Science 2        2023-03-14  12000
#                  4        2023-11-16  14000
# English          6        2023-07-25  16000
#                  8        2023-09-10  18000
# Geography        7        2023-08-17  17000
# Mathematics      3        2023-04-10  13000
#                  9        2023-10-05  19000
# Physics          0        2023-01-10  10000

# %% [markdown]
# # **Data Visualization**

# %%
studentsDf.Course.value_counts().plot()
# Out:
# <Axes: >

# %%
studentsDf.Course.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
studentsDf.Course.value_counts(normalize=True).plot(kind="pie")
# Out:
# <Axes: ylabel='Course'>

# %%
studentsDf.groupby(["Course"])[["Fee"]].aggregate(["min", "max", "mean"]).plot(kind="bar")
# Out:
# <Axes: xlabel='Course'>

# %% [markdown]
# # **Data Wrangling**

# %%
from typing import Dict, Union, List;
import pandas as pd;

studentsData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Teacher ID": [101, 102, 103, 101, 102]
};

students : pd.DataFrame = pd.DataFrame(studentsData);

students
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102

# %%
teachersData : Dict[str, List[Union[str, int]]] = {
    "Teacher ID": [101, 102, 103],
    "Course Name":["AI", "BlockChain","Maths"],
    "Teacher Name": ["Andrew Ng", "Steve Nouri", "Sir Zia"]
};

teachers = pd.DataFrame(teachersData);

teachers
# Out:
#    Teacher ID Course Name Teacher Name
# 0         101          AI    Andrew Ng
# 1         102  BlockChain  Steve Nouri
# 2         103       Maths      Sir Zia

# %%
studentFeesData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Fee Pay": [1500, 1500, 1500, 1500, 1500]
};

studentFees = pd.DataFrame(studentFeesData);

studentFees
# Out:
#    Student ID  Fee Pay
# 0           1     1500
# 1           2     1500
# 2           3     1500
# 3           4     1500
# 4           5     1500

# %%
students.info()

teachers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Teacher ID  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Teacher ID    3 non-null      int64
#  1   Course Name   3 non-null      object
#  2   Teacher Name  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
display(students);

display(teachers);
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    Teacher ID Course Name Teacher Name
# 0         101          AI    Andrew Ng
# 1         102  BlockChain  Steve Nouri
# 2         103       Maths      Sir Zia

# %%
df1 : pd.DataFrame = pd.merge(students, teachers);

df1
# Out:
#    Student ID     Name  Teacher ID Course Name Teacher Name
# 0           1    Alice         101          AI    Andrew Ng
# 1           4    David         101          AI    Andrew Ng
# 2           2      Bob         102  BlockChain  Steve Nouri
# 3           5      Eva         102  BlockChain  Steve Nouri
# 4           3  Charlie         103       Maths      Sir Zia

# %%
display(students);

display(teachers);

df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID"); # On Represent Commom Column Or Row

df1
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    Teacher ID Course Name Teacher Name
# 0         101          AI    Andrew Ng
# 1         102  BlockChain  Steve Nouri
# 2         103       Maths      Sir Zia
#    Student ID     Name  Teacher ID Course Name Teacher Name
# 0           1    Alice         101          AI    Andrew Ng
# 1           4    David         101          AI    Andrew Ng
# 2           2      Bob         102  BlockChain  Steve Nouri
# 3           5      Eva         102  BlockChain  Steve Nouri
# 4           3  Charlie         103       Maths      Sir Zia

# %%
df2 : pd.DataFrame = pd.merge(students, studentFees); # Only 2 Columns Are Merge Otherwise It's Return Error

df2
# Out:
#    Student ID     Name  Teacher ID  Fee Pay
# 0           1    Alice         101     1500
# 1           2      Bob         102     1500
# 2           3  Charlie         103     1500
# 3           4    David         101     1500
# 4           5      Eva         102     1500

# %%
from typing import Dict, Union, List;
import pandas as pd;

studentsData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Teacher ID": [101, 102, 103, 101, 500]
};

students : pd.DataFrame = pd.DataFrame(studentsData);

teachersData : Dict[str, List[Union[str, int]]] = {
    "Teacher ID": [101, 102, 100],
    "Course Name":["AI", "BlockChain","Maths"],
    "Teacher Name": ["Andrew Ng", "Steve Nouri", "Sir Zia"]
};

teachers = pd.DataFrame(teachersData);

studentFeesData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Fee Pay": [1500, 1500, 1500, 1500, 1500]
};

studentFees = pd.DataFrame(studentFeesData);

# %%
display(students);

display(teachers);

df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID");

df1
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         500
#    Teacher ID Course Name Teacher Name
# 0         101          AI    Andrew Ng
# 1         102  BlockChain  Steve Nouri
# 2         100       Maths      Sir Zia
#    Student ID   Name  Teacher ID Course Name Teacher Name
# 0           1  Alice         101          AI    Andrew Ng
# 1           4  David         101          AI    Andrew Ng
# 2           2    Bob         102  BlockChain  Steve Nouri

# %%
df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID", how="inner"); # By Default Inner Join Method

df1
# Out:
#    Student ID   Name  Teacher ID Course Name Teacher Name
# 0           1  Alice         101          AI    Andrew Ng
# 1           4  David         101          AI    Andrew Ng
# 2           2    Bob         102  BlockChain  Steve Nouri

# %%
df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID", how="left");

df1
# Out:
#    Student ID     Name  Teacher ID Course Name Teacher Name
# 0           1    Alice         101          AI    Andrew Ng
# 1           2      Bob         102  BlockChain  Steve Nouri
# 2           3  Charlie         103         NaN          NaN
# 3           4    David         101          AI    Andrew Ng
# 4           5      Eva         500         NaN          NaN

# %%
df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID", how="right");

df1
# Out:
#    Student ID   Name  Teacher ID Course Name Teacher Name
# 0         1.0  Alice         101          AI    Andrew Ng
# 1         4.0  David         101          AI    Andrew Ng
# 2         2.0    Bob         102  BlockChain  Steve Nouri
# 3         NaN    NaN         100       Maths      Sir Zia

# %%
df1 : pd.DataFrame = pd.merge(students, teachers, on="Teacher ID", how="outer"); # It Returns Both Columns Output

df1 # First Return Same Columns & Left Columns Then Right Columns Result
# Out:
#    Student ID     Name  Teacher ID Course Name Teacher Name
# 0         1.0    Alice         101          AI    Andrew Ng
# 1         4.0    David         101          AI    Andrew Ng
# 2         2.0      Bob         102  BlockChain  Steve Nouri
# 3         3.0  Charlie         103         NaN          NaN
# 4         5.0      Eva         500         NaN          NaN
# 5         NaN      NaN         100       Maths      Sir Zia

# %%
display(students);

display(teachers);

df1 : pd.DataFrame = pd.merge(students, teachers, how="cross"); # This Method Every Left Row Merge To Every Right Column

df1 # But It Not Take On Value
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         500
#    Teacher ID Course Name Teacher Name
# 0         101          AI    Andrew Ng
# 1         102  BlockChain  Steve Nouri
# 2         100       Maths      Sir Zia
#     Student ID     Name  Teacher ID_x  Teacher ID_y Course Name Teacher Name
# 0            1    Alice           101           101          AI    Andrew Ng
# 1            1    Alice           101           102  BlockChain  Steve Nouri
# 2            1    Alice           101           100       Maths      Sir Zia
# 3            2      Bob           102           101          AI    Andrew Ng
# 4            2      Bob           102           102  BlockChain  Steve Nouri
# 5            2      Bob           102           100       Maths      Sir Zia
# 6            3  Charlie           103           101          AI    Andrew Ng
# 7            3  Charlie           103           102  BlockChain  Steve Nouri
# 8            3  Charlie           103           100       Maths      Sir Zia
# 9            4    David           101           101          AI    Andrew Ng
# 10           4    David           101           102  BlockChain  Steve Nouri
# 11           4    David           101           100       Maths      Sir Zia
# 12           5      Eva           500           101          AI    Andrew Ng
# 13           5      Eva           500           102  BlockChain  Steve Nouri
# 14           5      Eva           500           100       Maths      Sir Zia

# %%
from typing import Dict, Union, List;
import pandas as pd;

studentsData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Teacher ID": [101, 102, 103, 101, 500] # Teacher ID
};

students : pd.DataFrame = pd.DataFrame(studentsData);

teachersData : Dict[str, List[Union[str, int]]] = {
    "Teachers ID": [101, 102, 100], # Teachers ID
    "Course Name":["AI", "BlockChain","Maths"],
    "Teacher Name": ["Andrew Ng", "Steve Nouri", "Sir Zia"]
};

teachers = pd.DataFrame(teachersData);

studentFeesData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Fee Pay": [1500, 1500, 1500, 1500, 1500]
};

studentFees = pd.DataFrame(studentFeesData);

# %%
display(students);

display(teachers);
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         500
#    Teachers ID Course Name Teacher Name
# 0          101          AI    Andrew Ng
# 1          102  BlockChain  Steve Nouri
# 2          100       Maths      Sir Zia

# %%
df1 : pd.DataFrame = pd.merge(students, teachers,
                              left_on="Teacher ID", right_on="Teachers ID",
                              how="inner");

df1
# Out:
#    Student ID   Name  Teacher ID  Teachers ID Course Name Teacher Name
# 0           1  Alice         101          101          AI    Andrew Ng
# 1           4  David         101          101          AI    Andrew Ng
# 2           2    Bob         102          102  BlockChain  Steve Nouri

# %%
from typing import Dict, Union, List;
import pandas as pd;

studentsData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 3, 4, 5],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Teacher ID": [101, 102, 103, 101, 500]
};

students : pd.DataFrame = pd.DataFrame(studentsData);

teachersData : Dict[str, List[Union[str, int]]] = {
    "Teachers ID": [101, 102, 100],
    "Course Name":["AI", "BlockChain","Maths"],
    "Teacher Name": ["Andrew Ng", "Steve Nouri", "Sir Zia"]
};

teachers = pd.DataFrame(teachersData);

studentFeesData : Dict[str, List[Union[str, int]]] = {
    "Student ID": [1, 2, 2, 1, 5], # Student Double Fees Pay
    "Fee Pay": [1500, 1500, 1500, 1500, 1500]
};

studentFees = pd.DataFrame(studentFeesData);

# %%
studentFees
# Out:
#    Student ID  Fee Pay
# 0           1     1500
# 1           2     1500
# 2           2     1500
# 3           1     1500
# 4           5     1500

# %%
df3: pd.DataFrame = studentFees.groupby("Student ID").agg("sum");

df3
# Out:
#             Fee Pay
# Student ID
# 1              3000
# 2              3000
# 5              1500

# %%
students
# Out:
#    Student ID     Name  Teacher ID
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         500

# %%
df4 : pd.DataFrame  = pd.merge(students, df3,
                               left_on="Student ID", right_on="Fee Pay",
                               how="outer");

df4
# Out:
#    Student ID     Name  Teacher ID  Fee Pay
# 0         1.0    Alice       101.0      NaN
# 1         2.0      Bob       102.0      NaN
# 2         3.0  Charlie       103.0      NaN
# 3         4.0    David       101.0      NaN
# 4         5.0      Eva       500.0      NaN
# 5         NaN      NaN         NaN   3000.0
# 6         NaN      NaN         NaN   3000.0
# 7         NaN      NaN         NaN   1500.0

# %%
df4 : pd.DataFrame  = pd.merge(students, df3,
                               left_on="Student ID", right_index=True,
                               how="outer");

df4
# Out:
#    Student ID     Name  Teacher ID  Fee Pay
# 0           1    Alice         101   3000.0
# 1           2      Bob         102   3000.0
# 2           3  Charlie         103      NaN
# 3           4    David         101      NaN
# 4           5      Eva         500   1500.0

# %%
display(pd.concat([students, teachers, studentFees])); # Default Value In Zero Axis (Top To Bottom)
# Out:
#    Student ID     Name  Teacher ID  Teachers ID Course Name Teacher Name  \
# 0         1.0    Alice       101.0          NaN         NaN          NaN
# 1         2.0      Bob       102.0          NaN         NaN          NaN
# 2         3.0  Charlie       103.0          NaN         NaN          NaN
# 3         4.0    David       101.0          NaN         NaN          NaN
# 4         5.0      Eva       500.0          NaN         NaN          NaN
# 0         NaN      NaN         NaN        101.0          AI    Andrew Ng
# 1         NaN      NaN         NaN        102.0  BlockChain  Steve Nouri
# 2         NaN      NaN         NaN        100.0       Maths      Sir Zia
# 0         1.0      NaN         NaN          NaN         NaN          NaN
# 1         2.0      NaN         NaN          NaN         NaN          NaN
# 2         2.0      NaN         NaN          NaN         NaN          NaN
# 3         1.0      NaN         NaN          NaN         NaN          NaN
# 4         5.0      NaN         NaN          NaN         NaN          NaN
#
#    Fee Pay
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 0      NaN
# 1      NaN
# 2      NaN
# 0   1500.0
# 1   1500.0
# 2   1500.0
# 3   1500.0
# 4   1500.0

# %%
display(pd.concat([students, teachers, studentFees], axis=1)); # Left To Right
# Out:
#    Student ID     Name  Teacher ID  Teachers ID Course Name Teacher Name  \
# 0           1    Alice         101        101.0          AI    Andrew Ng
# 1           2      Bob         102        102.0  BlockChain  Steve Nouri
# 2           3  Charlie         103        100.0       Maths      Sir Zia
# 3           4    David         101          NaN         NaN          NaN
# 4           5      Eva         500          NaN         NaN          NaN
#
#    Student ID  Fee Pay
# 0           1     1500
# 1           2     1500
# 2           2     1500
# 3           1     1500
# 4           5     1500
