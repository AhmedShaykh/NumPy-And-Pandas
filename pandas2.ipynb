# %%
import pandas as pd;
import numpy as np;
from nptyping import NDArray, Shape, Int64;

total : int = 10000;

s1 : NDArray[Shape[str(total)], Int64] = np.random.randint(80, 100, total);

print(len(s1));

s1
# Out:
# 10000
# array([98, 80, 93, ..., 93, 95, 98])

# %%
ss1: pd.Series = pd.Series(s1);

ss1
# Out:
# 0       98
# 1       80
# 2       93
# 3       80
# 4       85
#         ..
# 9995    82
# 9996    96
# 9997    93
# 9998    95
# 9999    98
# Length: 10000, dtype: int64

# %%
total : int = 10000;

s1 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(80, 100, (total, 5)); # Return 5 Rows Data

ss1: pd.DataFrame = pd.DataFrame(s1, columns=["s1","s2","s3","s4","s5"]);

s2 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(70, 79, (total, 5));

ss2: pd.DataFrame = pd.DataFrame(s2, columns=["s1","s2","s3","s4","s5"]);

s3 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(60, 69, (total, 5));

ss3: pd.DataFrame = pd.DataFrame(s3, columns=["s1","s2","s3","s4","s5"]);

s4 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(50, 59, (total, 5));

ss4: pd.DataFrame = pd.DataFrame(s4, columns=["s1","s2","s3","s4","s5"]);

s5 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(40, 49, (total, 5));

ss5: pd.DataFrame = pd.DataFrame(s5, columns=["s1","s2","s3","s4","s5"]);

s6 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(33, 39, (total, 5));

ss6: pd.DataFrame = pd.DataFrame(s6, columns=["s1","s2","s3","s4","s5"]);

s7 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(0, 32, (total, 5));

ss7: pd.DataFrame = pd.DataFrame(s7, columns=["s1","s2","s3","s4","s5"]);

print(len(ss1));

print(len(ss2));

print(len(ss3));

print(len(ss4));

print(len(ss5));

print(len(ss6));

print(len(ss7));
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000

# %%
ss1
# Out:
#       s1  s2  s3  s4  s5
# 0     90  99  85  93  86
# 1     95  87  85  85  96
# 2     96  91  98  94  87
# 3     80  89  81  92  92
# 4     85  85  95  91  91
# ...   ..  ..  ..  ..  ..
# 9995  97  95  84  98  81
# 9996  91  80  85  83  81
# 9997  88  98  80  91  89
# 9998  89  83  90  82  97
# 9999  97  97  82  88  90
#
# [10000 rows x 5 columns]

# %%
ss4
# Out:
#       s1  s2  s3  s4  s5
# 0     52  57  54  53  54
# 1     54  50  50  57  55
# 2     56  53  52  58  51
# 3     53  56  53  58  57
# 4     54  55  50  54  58
# ...   ..  ..  ..  ..  ..
# 9995  51  54  54  54  52
# 9996  50  56  55  51  54
# 9997  55  51  52  51  52
# 9998  55  57  56  53  57
# 9999  57  51  55  54  53
#
# [10000 rows x 5 columns]

# %%
ss6
# Out:
#       s1  s2  s3  s4  s5
# 0     33  37  37  38  35
# 1     36  37  33  35  36
# 2     33  36  33  35  37
# 3     34  37  38  38  33
# 4     35  38  33  34  35
# ...   ..  ..  ..  ..  ..
# 9995  35  35  34  36  38
# 9996  34  37  35  34  34
# 9997  33  35  37  34  37
# 9998  36  34  35  37  36
# 9999  36  33  33  36  34
#
# [10000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]);

df
# Out:
#       s1  s2  s3  s4  s5
# 0     90  99  85  93  86
# 1     95  87  85  85  96
# 2     96  91  98  94  87
# 3     80  89  81  92  92
# 4     85  85  95  91  91
# ...   ..  ..  ..  ..  ..
# 9995  24  19  12   9  29
# 9996  21   7   7  17  23
# 9997   8  28   0  14  29
# 9998   2  13  18  29  16
# 9999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]).reset_index();

df
# Out:
#        index  s1  s2  s3  s4  s5
# 0          0  90  99  85  93  86
# 1          1  95  87  85  85  96
# 2          2  96  91  98  94  87
# 3          3  80  89  81  92  92
# 4          4  85  85  95  91  91
# ...      ...  ..  ..  ..  ..  ..
# 69995   9995  24  19  12   9  29
# 69996   9996  21   7   7  17  23
# 69997   9997   8  28   0  14  29
# 69998   9998   2  13  18  29  16
# 69999   9999  28  26   1  15  25
#
# [70000 rows x 6 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]).reset_index(drop = True); # Remove Old Index Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int64
#  1   s2      70000 non-null  int64
#  2   s3      70000 non-null  int64
#  3   s4      70000 non-null  int64
#  4   s5      70000 non-null  int64
# dtypes: int64(5)
# memory usage: 2.7 MB

# %%
df.describe()
# Out:
#                  s1          s2            s3            s4            s5
# count  70000.000000  70000.0000  70000.000000  70000.000000  70000.000000
# mean      53.803000     53.7848     53.784014     53.792886     53.777057
# std       23.393119     23.4418     23.410003     23.379119     23.415399
# min        0.000000      0.0000      0.000000      0.000000      0.000000
# 25%       37.000000     37.0000     37.000000     37.000000     37.000000
# 50%       54.000000     54.0000     54.000000     54.000000     54.000000
# 75%       72.000000     72.0000     72.000000     72.000000     72.000000
# max       99.000000     99.0000     99.000000     99.000000     99.000000

# %%
df.head() # Default Show First 5 Rows
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91

# %%
df.head(10)
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91
# 5  92  85  93  99  84
# 6  90  90  93  81  81
# 7  80  88  90  89  94
# 8  96  93  96  90  99
# 9  83  85  93  88  95

# %%
df.tail() # Default Show Last 5 Rows
# Out:
#        s1  s2  s3  s4  s5
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25

# %%
df.tail(9)
# Out:
#        s1  s2  s3  s4  s5
# 69991  31  19  28  19   3
# 69992  14  29  15   6  27
# 69993   8  19  26   0   1
# 69994  29   6   3  30   3
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25

# %%
df.to_csv("data.csv", index=False) # Create CSV File And Add Previous Function Data

# %%
df1 : pd.DataFrame = pd.read_csv("./data.csv");

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91

# %%
df1
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %% [markdown]
# # **Apply Operations On Columns**

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91

# %%
df["s5"]
# Out:
# 0        86
# 1        96
# 2        87
# 3        92
# 4        91
#          ..
# 69995    29
# 69996    23
# 69997    29
# 69998    16
# 69999    25
# Name: s5, Length: 70000, dtype: int64

# %%
df.s5
# Out:
# 0        86
# 1        96
# 2        87
# 3        92
# 4        91
#          ..
# 69995    29
# 69996    23
# 69997    29
# 69998    16
# 69999    25
# Name: s5, Length: 70000, dtype: int64

# %%
df[["s1","s5","s3","s4"]] # Get Multiple Columns
# Out:
#        s1  s5  s3  s4
# 0      90  86  85  93
# 1      95  96  85  85
# 2      96  87  98  94
# 3      80  92  81  92
# 4      85  91  95  91
# ...    ..  ..  ..  ..
# 69995  24  29  12   9
# 69996  21  23   7  17
# 69997   8  29   0  14
# 69998   2  16  18  29
# 69999  28  25   1  15
#
# [70000 rows x 4 columns]

# %%
df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df["Total"] = 500; # Add New Column

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      90  99  85  93  86    500
# 1      95  87  85  85  96    500
# 2      96  91  98  94  87    500
# 3      80  89  81  92  92    500
# 4      85  85  95  91  91    500
# ...    ..  ..  ..  ..  ..    ...
# 69995  24  19  12   9  29    500
# 69996  21   7   7  17  23    500
# 69997   8  28   0  14  29    500
# 69998   2  13  18  29  16    500
# 69999  28  26   1  15  25    500
#
# [70000 rows x 6 columns]

# %%
df["Total"] = 300; # Update Column Values

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      90  99  85  93  86    300
# 1      95  87  85  85  96    300
# 2      96  91  98  94  87    300
# 3      80  89  81  92  92    300
# 4      85  85  95  91  91    300
# ...    ..  ..  ..  ..  ..    ...
# 69995  24  19  12   9  29    300
# 69996  21   7   7  17  23    300
# 69997   8  28   0  14  29    300
# 69998   2  13  18  29  16    300
# 69999  28  26   1  15  25    300
#
# [70000 rows x 6 columns]

# %%
del df["Total"]; # Delete Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df.Total = 500; # Not Add Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df["Total"] = 500;

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      90  99  85  93  86    500
# 1      95  87  85  85  96    500
# 2      96  91  98  94  87    500
# 3      80  89  81  92  92    500
# 4      85  85  95  91  91    500
# ...    ..  ..  ..  ..  ..    ...
# 69995  24  19  12   9  29    500
# 69996  21   7   7  17  23    500
# 69997   8  28   0  14  29    500
# 69998   2  13  18  29  16    500
# 69999  28  26   1  15  25    500
#
# [70000 rows x 6 columns]

# %%
df.Total = 300; # And Not Update Column Only Get Column Of This Method

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      90  99  85  93  86    500
# 1      95  87  85  85  96    500
# 2      96  91  98  94  87    500
# 3      80  89  81  92  92    500
# 4      85  85  95  91  91    500
# ...    ..  ..  ..  ..  ..    ...
# 69995  24  19  12   9  29    500
# 69996  21   7   7  17  23    500
# 69997   8  28   0  14  29    500
# 69998   2  13  18  29  16    500
# 69999  28  26   1  15  25    500
#
# [70000 rows x 6 columns]

# %%
del df["Total"];

df
# Out:
#        s1  s2  s3  s4  s5
# 0      90  99  85  93  86
# 1      95  87  85  85  96
# 2      96  91  98  94  87
# 3      80  89  81  92  92
# 4      85  85  95  91  91
# ...    ..  ..  ..  ..  ..
# 69995  24  19  12   9  29
# 69996  21   7   7  17  23
# 69997   8  28   0  14  29
# 69998   2  13  18  29  16
# 69999  28  26   1  15  25
#
# [70000 rows x 5 columns]

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91

# %%
dfTotal = df["s1"] + df["s2"] + df["s3"] + df["s4"] + df["s5"]; # All Columns Values Are Sum

dfTotal
# Out:
# 0        453
# 1        448
# 2        466
# 3        434
# 4        447
#         ...
# 69995     93
# 69996     75
# 69997     79
# 69998     78
# 69999     95
# Length: 70000, dtype: int64

# %%
df["Obtained"] = dfTotal;

df["Total"] = 500;

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total
# 0      90  99  85  93  86       453    500
# 1      95  87  85  85  96       448    500
# 2      96  91  98  94  87       466    500
# 3      80  89  81  92  92       434    500
# 4      85  85  95  91  91       447    500
# ...    ..  ..  ..  ..  ..       ...    ...
# 69995  24  19  12   9  29        93    500
# 69996  21   7   7  17  23        75    500
# 69997   8  28   0  14  29        79    500
# 69998   2  13  18  29  16        78    500
# 69999  28  26   1  15  25        95    500
#
# [70000 rows x 7 columns]

# %%
df["Percentage"] = df["Obtained"] / df["Total"] * 100;

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage
# 0      90  99  85  93  86       453    500        90.6
# 1      95  87  85  85  96       448    500        89.6
# 2      96  91  98  94  87       466    500        93.2
# 3      80  89  81  92  92       434    500        86.8
# 4      85  85  95  91  91       447    500        89.4
# ...    ..  ..  ..  ..  ..       ...    ...         ...
# 69995  24  19  12   9  29        93    500        18.6
# 69996  21   7   7  17  23        75    500        15.0
# 69997   8  28   0  14  29        79    500        15.8
# 69998   2  13  18  29  16        78    500        15.6
# 69999  28  26   1  15  25        95    500        19.0
#
# [70000 rows x 8 columns]

# %%
def grade(per: int) -> str:

    if per >= 80:

        return "A+";

    elif per >= 70:

        return "A";

    elif per >= 60:

        return "B";

    elif per >= 50:

        return "C";

    elif per >= 40:

        return "D";

    elif per >= 33:

        return "E";

    else:

        return "F";

grade(82)
# Out:
# 'A+'

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5  Obtained  Total  Percentage
# 0  90  99  85  93  86       453    500        90.6
# 1  95  87  85  85  96       448    500        89.6
# 2  96  91  98  94  87       466    500        93.2
# 3  80  89  81  92  92       434    500        86.8
# 4  85  85  95  91  91       447    500        89.4

# %%
df["Percentage"].apply(grade)
# Out:
# 0        A+
# 1        A+
# 2        A+
# 3        A+
# 4        A+
#          ..
# 69995     F
# 69996     F
# 69997     F
# 69998     F
# 69999     F
# Name: Percentage, Length: 70000, dtype: object

# %%
df["Grade"] = df["Percentage"].apply(grade);

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade
# 0      90  99  85  93  86       453    500        90.6    A+
# 1      95  87  85  85  96       448    500        89.6    A+
# 2      96  91  98  94  87       466    500        93.2    A+
# 3      80  89  81  92  92       434    500        86.8    A+
# 4      85  85  95  91  91       447    500        89.4    A+
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...
# 69995  24  19  12   9  29        93    500        18.6     F
# 69996  21   7   7  17  23        75    500        15.0     F
# 69997   8  28   0  14  29        79    500        15.8     F
# 69998   2  13  18  29  16        78    500        15.6     F
# 69999  28  26   1  15  25        95    500        19.0     F
#
# [70000 rows x 9 columns]

# %% [markdown]
# # **Apply Custom Function On Multiple Columns**

# %%
df1.head(10)
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91
# 5  92  85  93  99  84
# 6  90  90  93  81  81
# 7  80  88  90  89  94
# 8  96  93  96  90  99
# 9  83  85  93  88  95

# %%
df1[0:10] # Direct Slicing Apply
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91
# 5  92  85  93  99  84
# 6  90  90  93  81  81
# 7  80  88  90  89  94
# 8  96  93  96  90  99
# 9  83  85  93  88  95

# %%
df1.iloc[1:11, 1:4] # Pandas Slicing Apply On (Rows & Columns)
# Out:
#     s2  s3  s4
# 1   87  85  85
# 2   91  98  94
# 3   89  81  92
# 4   85  95  91
# 5   85  93  99
# 6   90  93  81
# 7   88  90  89
# 8   93  96  90
# 9   85  93  88
# 10  93  89  86

# %%
df1.loc[1:11] # The Only One Slice Method That Can Return End Value
# Out:
#     s1  s2  s3  s4  s5
# 1   95  87  85  85  96
# 2   96  91  98  94  87
# 3   80  89  81  92  92
# 4   85  85  95  91  91
# 5   92  85  93  99  84
# 6   90  90  93  81  81
# 7   80  88  90  89  94
# 8   96  93  96  90  99
# 9   83  85  93  88  95
# 10  94  93  89  86  87
# 11  83  95  86  95  83

# %%
df1.loc[1:10, "s1":"s4"] # Direct Slicing Apply On Rows & Columns Labels
# Out:
#     s1  s2  s3  s4
# 1   95  87  85  85
# 2   96  91  98  94
# 3   80  89  81  92
# 4   85  85  95  91
# 5   92  85  93  99
# 6   90  90  93  81
# 7   80  88  90  89
# 8   96  93  96  90
# 9   83  85  93  88
# 10  94  93  89  86

# %%
df1.at[4,"s1"] # It Return Only Single Value On Label
# Out:
# 85

# %%
df1.iat[4,0] # It Return Only Single Value On Index
# Out:
# 85

# %%
df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  90  99  85  93  86
# 1  95  87  85  85  96
# 2  96  91  98  94  87
# 3  80  89  81  92  92
# 4  85  85  95  91  91

# %%
def fnObtained(s1: int, s2: int, s3: int, s4: int, s5: int) -> int:

    return s1 + s2 + s3 + s4 + s5;

df1["Obtained"] = df1[["s1", "s2", "s3", "s4", "s5"]].apply(lambda x: fnObtained(* x), axis = 1); # Single Output & Multi Input

df1
# Out:
#        s1  s2  s3  s4  s5  Obtained
# 0      90  99  85  93  86       453
# 1      95  87  85  85  96       448
# 2      96  91  98  94  87       466
# 3      80  89  81  92  92       434
# 4      85  85  95  91  91       447
# ...    ..  ..  ..  ..  ..       ...
# 69995  24  19  12   9  29        93
# 69996  21   7   7  17  23        75
# 69997   8  28   0  14  29        79
# 69998   2  13  18  29  16        78
# 69999  28  26   1  15  25        95
#
# [70000 rows x 6 columns]

# %%
def fnObtained(s1: int, s2: int, s3: int, s4: int, s5: int) -> tuple[int, int, float, str]:

    total: int = 500;

    obtained :int = s1 + s2 + s3 + s4 + s5;

    per : float = obtained / total * 100;

    grade : str = "";

    if per >= 80:
        grade = "A+";
    elif per >= 70:
        grade = "A";
    elif per >= 60:
        grade = "B";
    elif per >= 50:
        grade = "C";
    elif per >= 40:
        grade = "D";
    elif per >= 33:
        grade = "E";
    else:
        grade = "F";

    return total, obtained, per, grade;

df1[["Total","Obtained", "Percentage", "Grade"]] = df1[["s1", "s2", "s3", "s4", "s5"]].apply(lambda x: fnObtained(* x),
                                                                                             axis=1,
                                                                                             result_type="expand"); # Return Value Type Specify

display(df1); # Multi Output & Multi Input
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade
# 0      90  99  85  93  86       453    500        90.6    A+
# 1      95  87  85  85  96       448    500        89.6    A+
# 2      96  91  98  94  87       466    500        93.2    A+
# 3      80  89  81  92  92       434    500        86.8    A+
# 4      85  85  95  91  91       447    500        89.4    A+
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...
# 69995  24  19  12   9  29        93    500        18.6     F
# 69996  21   7   7  17  23        75    500        15.0     F
# 69997   8  28   0  14  29        79    500        15.8     F
# 69998   2  13  18  29  16        78    500        15.6     F
# 69999  28  26   1  15  25        95    500        19.0     F
#
# [70000 rows x 9 columns]

# %%
from typing import Dict;

remark : Dict[str, str] = {
    "A+" : "Excellent",
    "A" : "Very Good",
    "B" : "Good",
    "C" : "Fair",
    "D" : "Poor",
    "E" : "Very Poor",
    "F": "Fail"
};

df1["Remark"] = df1.Grade.map(remark);

display(df1);
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade     Remark
# 0      90  99  85  93  86       453    500        90.6    A+  Excellent
# 1      95  87  85  85  96       448    500        89.6    A+  Excellent
# 2      96  91  98  94  87       466    500        93.2    A+  Excellent
# 3      80  89  81  92  92       434    500        86.8    A+  Excellent
# 4      85  85  95  91  91       447    500        89.4    A+  Excellent
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...        ...
# 69995  24  19  12   9  29        93    500        18.6     F       Fail
# 69996  21   7   7  17  23        75    500        15.0     F       Fail
# 69997   8  28   0  14  29        79    500        15.8     F       Fail
# 69998   2  13  18  29  16        78    500        15.6     F       Fail
# 69999  28  26   1  15  25        95    500        19.0     F       Fail
#
# [70000 rows x 10 columns]

# %% [markdown]
# # **Type Casting On Columns**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int64
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 5.3+ MB

# %%
df1["s1"] = df1["s1"].astype(np.int32);

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int32
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int32(1), int64(6), object(2)
# memory usage: 5.1+ MB

# %%
df1["s1"] = df1["s1"].apply(np.int64);

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int64
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 5.3+ MB
