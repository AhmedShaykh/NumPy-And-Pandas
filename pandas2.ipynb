# %%
import numpy as np;
from nptyping import NDArray, Shape, Int64;

total : int = 10000;

s1 : NDArray[Shape[str(total)], Int64] = np.random.randint(80, 100, total);

print(len(s1));

s1
# Out:
# 10000
# array([90, 93, 99, ..., 98, 99, 94])

# %%
import pandas as pd;

ss1: pd.Series = pd.Series(s1);

ss1
# Out:
# 0       90
# 1       93
# 2       99
# 3       96
# 4       80
#         ..
# 9995    89
# 9996    89
# 9997    98
# 9998    99
# 9999    94
# Length: 10000, dtype: int64

# %%
total : int = 10000;

s1 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(80, 100, (total, 5)); # Return 5 Rows Data

ss1: pd.DataFrame = pd.DataFrame(s1, columns=["s1","s2","s3","s4","s5"]);

s2 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(70, 79, (total, 5));

ss2: pd.DataFrame = pd.DataFrame(s2, columns=["s1","s2","s3","s4","s5"]);

s3 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(60, 69, (total, 5));

ss3: pd.DataFrame = pd.DataFrame(s3, columns=["s1","s2","s3","s4","s5"]);

s4 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(50, 59, (total, 5));

ss4: pd.DataFrame = pd.DataFrame(s4, columns=["s1","s2","s3","s4","s5"]);

s5 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(40, 49, (total, 5));

ss5: pd.DataFrame = pd.DataFrame(s5, columns=["s1","s2","s3","s4","s5"]);

s6 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(33, 39, (total, 5));

ss6: pd.DataFrame = pd.DataFrame(s6, columns=["s1","s2","s3","s4","s5"]);

s7 : NDArray[Shape[str(total) + "5"], Int64] = np.random.randint(0, 32, (total, 5));

ss7: pd.DataFrame = pd.DataFrame(s7, columns=["s1","s2","s3","s4","s5"]);

print(len(ss1));

print(len(ss2));

print(len(ss3));

print(len(ss4));

print(len(ss5));

print(len(ss6));

print(len(ss7));
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000

# %%
ss1
# Out:
#       s1  s2  s3  s4  s5
# 0     94  91  98  95  85
# 1     91  84  91  93  81
# 2     99  84  89  82  83
# 3     94  84  93  94  81
# 4     81  99  85  96  81
# ...   ..  ..  ..  ..  ..
# 9995  84  98  83  97  92
# 9996  80  85  98  94  91
# 9997  83  92  84  81  87
# 9998  93  82  80  96  88
# 9999  88  82  89  95  91
#
# [10000 rows x 5 columns]

# %%
ss4
# Out:
#       s1  s2  s3  s4  s5
# 0     50  55  53  51  51
# 1     58  55  55  51  55
# 2     51  56  53  56  58
# 3     53  50  57  52  56
# 4     50  54  54  50  56
# ...   ..  ..  ..  ..  ..
# 9995  58  50  53  58  50
# 9996  57  57  51  56  52
# 9997  57  50  51  52  56
# 9998  51  52  53  50  57
# 9999  50  53  58  52  51
#
# [10000 rows x 5 columns]

# %%
ss6
# Out:
#       s1  s2  s3  s4  s5
# 0     34  34  33  37  35
# 1     35  37  38  36  33
# 2     34  34  35  38  33
# 3     35  37  37  34  33
# 4     33  36  38  36  38
# ...   ..  ..  ..  ..  ..
# 9995  35  37  34  35  34
# 9996  35  33  35  38  34
# 9997  35  33  38  37  36
# 9998  36  33  36  35  33
# 9999  38  38  34  36  37
#
# [10000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]);

df
# Out:
#       s1  s2  s3  s4  s5
# 0     94  91  98  95  85
# 1     91  84  91  93  81
# 2     99  84  89  82  83
# 3     94  84  93  94  81
# 4     81  99  85  96  81
# ...   ..  ..  ..  ..  ..
# 9995   2  19  22  20  13
# 9996  28  26  22   9  29
# 9997   9  24  11  28   4
# 9998   2   0   5  27   1
# 9999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]).reset_index();

df
# Out:
#        index  s1  s2  s3  s4  s5
# 0          0  94  91  98  95  85
# 1          1  91  84  91  93  81
# 2          2  99  84  89  82  83
# 3          3  94  84  93  94  81
# 4          4  81  99  85  96  81
# ...      ...  ..  ..  ..  ..  ..
# 69995   9995   2  19  22  20  13
# 69996   9996  28  26  22   9  29
# 69997   9997   9  24  11  28   4
# 69998   9998   2   0   5  27   1
# 69999   9999  27  21   6  22  20
#
# [70000 rows x 6 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7]).reset_index(drop = True); # Remove Old Index Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int64
#  1   s2      70000 non-null  int64
#  2   s3      70000 non-null  int64
#  3   s4      70000 non-null  int64
#  4   s5      70000 non-null  int64
# dtypes: int64(5)
# memory usage: 2.7 MB

# %%
df.describe()
# Out:
#                  s1            s2            s3            s4            s5
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.779371     53.788229     53.778443     53.763643     53.796114
# std       23.372744     23.406174     23.439040     23.380068     23.384484
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       37.000000     37.000000     37.000000     37.000000     37.000000
# 50%       54.000000     54.000000     54.000000     54.000000     54.000000
# 75%       72.000000     72.000000     72.000000     72.000000     72.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000

# %%
df.head() # Default Show First 5 Rows
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81

# %%
df.head(10)
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81
# 5  80  88  81  90  99
# 6  84  81  81  89  86
# 7  98  90  80  90  80
# 8  87  80  90  91  86
# 9  86  99  91  82  97

# %%
df.tail() # Default Show Last 5 Rows
# Out:
#        s1  s2  s3  s4  s5
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20

# %%
df.tail(9)
# Out:
#        s1  s2  s3  s4  s5
# 69991   0   1  12  20  22
# 69992  26  21  30  10  20
# 69993  30  15  26  26  28
# 69994   9  27   1  27  22
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20

# %%
df.to_csv("data.csv", index=False) # Create CSV File And Add Previous Function Data

# %%
df1 : pd.DataFrame = pd.read_csv("./data.csv");

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81

# %%
df1
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %% [markdown]
# # **Apply Operations On Columns**

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81

# %%
df["s5"]
# Out:
# 0        85
# 1        81
# 2        83
# 3        81
# 4        81
#          ..
# 69995    13
# 69996    29
# 69997     4
# 69998     1
# 69999    20
# Name: s5, Length: 70000, dtype: int64

# %%
df.s5
# Out:
# 0        85
# 1        81
# 2        83
# 3        81
# 4        81
#          ..
# 69995    13
# 69996    29
# 69997     4
# 69998     1
# 69999    20
# Name: s5, Length: 70000, dtype: int64

# %%
df[["s1","s5","s3","s4"]] # Get Multiple Columns
# Out:
#        s1  s5  s3  s4
# 0      94  85  98  95
# 1      91  81  91  93
# 2      99  83  89  82
# 3      94  81  93  94
# 4      81  81  85  96
# ...    ..  ..  ..  ..
# 69995   2  13  22  20
# 69996  28  29  22   9
# 69997   9   4  11  28
# 69998   2   1   5  27
# 69999  27  20   6  22
#
# [70000 rows x 4 columns]

# %%
df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df["Total"] = 500; # Add New Column

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      94  91  98  95  85    500
# 1      91  84  91  93  81    500
# 2      99  84  89  82  83    500
# 3      94  84  93  94  81    500
# 4      81  99  85  96  81    500
# ...    ..  ..  ..  ..  ..    ...
# 69995   2  19  22  20  13    500
# 69996  28  26  22   9  29    500
# 69997   9  24  11  28   4    500
# 69998   2   0   5  27   1    500
# 69999  27  21   6  22  20    500
#
# [70000 rows x 6 columns]

# %%
df["Total"] = 300; # Update Column Values

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      94  91  98  95  85    300
# 1      91  84  91  93  81    300
# 2      99  84  89  82  83    300
# 3      94  84  93  94  81    300
# 4      81  99  85  96  81    300
# ...    ..  ..  ..  ..  ..    ...
# 69995   2  19  22  20  13    300
# 69996  28  26  22   9  29    300
# 69997   9  24  11  28   4    300
# 69998   2   0   5  27   1    300
# 69999  27  21   6  22  20    300
#
# [70000 rows x 6 columns]

# %%
del df["Total"]; # Delete Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df.Total = 500; # Not Add Column

df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df["Total"] = 500;

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      94  91  98  95  85    500
# 1      91  84  91  93  81    500
# 2      99  84  89  82  83    500
# 3      94  84  93  94  81    500
# 4      81  99  85  96  81    500
# ...    ..  ..  ..  ..  ..    ...
# 69995   2  19  22  20  13    500
# 69996  28  26  22   9  29    500
# 69997   9  24  11  28   4    500
# 69998   2   0   5  27   1    500
# 69999  27  21   6  22  20    500
#
# [70000 rows x 6 columns]

# %%
df.Total = 300; # And Not Update Column Only Get Column Of This Method

df
# Out:
#        s1  s2  s3  s4  s5  Total
# 0      94  91  98  95  85    500
# 1      91  84  91  93  81    500
# 2      99  84  89  82  83    500
# 3      94  84  93  94  81    500
# 4      81  99  85  96  81    500
# ...    ..  ..  ..  ..  ..    ...
# 69995   2  19  22  20  13    500
# 69996  28  26  22   9  29    500
# 69997   9  24  11  28   4    500
# 69998   2   0   5  27   1    500
# 69999  27  21   6  22  20    500
#
# [70000 rows x 6 columns]

# %%
del df["Total"];

df
# Out:
#        s1  s2  s3  s4  s5
# 0      94  91  98  95  85
# 1      91  84  91  93  81
# 2      99  84  89  82  83
# 3      94  84  93  94  81
# 4      81  99  85  96  81
# ...    ..  ..  ..  ..  ..
# 69995   2  19  22  20  13
# 69996  28  26  22   9  29
# 69997   9  24  11  28   4
# 69998   2   0   5  27   1
# 69999  27  21   6  22  20
#
# [70000 rows x 5 columns]

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81

# %%
dfTotal = df["s1"] + df["s2"] + df["s3"] + df["s4"] + df["s5"]; # All Columns Values Are Sum

dfTotal
# Out:
# 0        463
# 1        440
# 2        437
# 3        446
# 4        442
#         ...
# 69995     76
# 69996    114
# 69997     76
# 69998     35
# 69999     96
# Length: 70000, dtype: int64

# %%
df["Obtained"] = dfTotal;

df["Total"] = 500;

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total
# 0      94  91  98  95  85       463    500
# 1      91  84  91  93  81       440    500
# 2      99  84  89  82  83       437    500
# 3      94  84  93  94  81       446    500
# 4      81  99  85  96  81       442    500
# ...    ..  ..  ..  ..  ..       ...    ...
# 69995   2  19  22  20  13        76    500
# 69996  28  26  22   9  29       114    500
# 69997   9  24  11  28   4        76    500
# 69998   2   0   5  27   1        35    500
# 69999  27  21   6  22  20        96    500
#
# [70000 rows x 7 columns]

# %%
df["Percentage"] = df["Obtained"] / df["Total"] * 100;

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage
# 0      94  91  98  95  85       463    500        92.6
# 1      91  84  91  93  81       440    500        88.0
# 2      99  84  89  82  83       437    500        87.4
# 3      94  84  93  94  81       446    500        89.2
# 4      81  99  85  96  81       442    500        88.4
# ...    ..  ..  ..  ..  ..       ...    ...         ...
# 69995   2  19  22  20  13        76    500        15.2
# 69996  28  26  22   9  29       114    500        22.8
# 69997   9  24  11  28   4        76    500        15.2
# 69998   2   0   5  27   1        35    500         7.0
# 69999  27  21   6  22  20        96    500        19.2
#
# [70000 rows x 8 columns]

# %%
def grade(per: int) -> str:

    if per >= 80:

        return "A+";

    elif per >= 70:

        return "A";

    elif per >= 60:

        return "B";

    elif per >= 50:

        return "C";

    elif per >= 40:

        return "D";

    elif per >= 33:

        return "E";

    else:

        return "F";

grade(82)
# Out:
# 'A+'

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5  Obtained  Total  Percentage
# 0  94  91  98  95  85       463    500        92.6
# 1  91  84  91  93  81       440    500        88.0
# 2  99  84  89  82  83       437    500        87.4
# 3  94  84  93  94  81       446    500        89.2
# 4  81  99  85  96  81       442    500        88.4

# %%
df["Percentage"].apply(grade)
# Out:
# 0        A+
# 1        A+
# 2        A+
# 3        A+
# 4        A+
#          ..
# 69995     F
# 69996     F
# 69997     F
# 69998     F
# 69999     F
# Name: Percentage, Length: 70000, dtype: object

# %%
df["Grade"] = df["Percentage"].apply(grade);

df
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade
# 0      94  91  98  95  85       463    500        92.6    A+
# 1      91  84  91  93  81       440    500        88.0    A+
# 2      99  84  89  82  83       437    500        87.4    A+
# 3      94  84  93  94  81       446    500        89.2    A+
# 4      81  99  85  96  81       442    500        88.4    A+
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...
# 69995   2  19  22  20  13        76    500        15.2     F
# 69996  28  26  22   9  29       114    500        22.8     F
# 69997   9  24  11  28   4        76    500        15.2     F
# 69998   2   0   5  27   1        35    500         7.0     F
# 69999  27  21   6  22  20        96    500        19.2     F
#
# [70000 rows x 9 columns]

# %% [markdown]
# # **Apply Custom Function On Multiple Columns**

# %%
df1.head(10)
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81
# 5  80  88  81  90  99
# 6  84  81  81  89  86
# 7  98  90  80  90  80
# 8  87  80  90  91  86
# 9  86  99  91  82  97

# %%
df1[0:10] # Direct Slicing Apply
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81
# 5  80  88  81  90  99
# 6  84  81  81  89  86
# 7  98  90  80  90  80
# 8  87  80  90  91  86
# 9  86  99  91  82  97

# %%
df1.iloc[1:11, 1:4] # Pandas Slicing Apply On (Rows & Columns)
# Out:
#     s2  s3  s4
# 1   84  91  93
# 2   84  89  82
# 3   84  93  94
# 4   99  85  96
# 5   88  81  90
# 6   81  81  89
# 7   90  80  90
# 8   80  90  91
# 9   99  91  82
# 10  99  99  93

# %%
df1.loc[1:11] # The Only One Slice Method That Can Return End Value
# Out:
#     s1  s2  s3  s4  s5
# 1   91  84  91  93  81
# 2   99  84  89  82  83
# 3   94  84  93  94  81
# 4   81  99  85  96  81
# 5   80  88  81  90  99
# 6   84  81  81  89  86
# 7   98  90  80  90  80
# 8   87  80  90  91  86
# 9   86  99  91  82  97
# 10  94  99  99  93  81
# 11  98  96  83  86  95

# %%
df1.loc[1:10, "s1":"s4"] # Direct Slicing Apply On Rows & Columns Labels
# Out:
#     s1  s2  s3  s4
# 1   91  84  91  93
# 2   99  84  89  82
# 3   94  84  93  94
# 4   81  99  85  96
# 5   80  88  81  90
# 6   84  81  81  89
# 7   98  90  80  90
# 8   87  80  90  91
# 9   86  99  91  82
# 10  94  99  99  93

# %%
df1.at[4,"s1"] # It Return Only Single Value On Label
# Out:
# 81

# %%
df1.iat[4,3] # It Return Only Single Value On Index
# Out:
# 96

# %%
df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  94  91  98  95  85
# 1  91  84  91  93  81
# 2  99  84  89  82  83
# 3  94  84  93  94  81
# 4  81  99  85  96  81

# %%
def fnObtained(s1: int, s2: int, s3: int, s4: int, s5: int) -> int:

    return s1 + s2 + s3 + s4 + s5;

df1["Obtained"] = df1[["s1", "s2", "s3", "s4", "s5"]].apply(lambda x: fnObtained(* x), axis = 1); # Single Output & Multi Input

df1
# Out:
#        s1  s2  s3  s4  s5  Obtained
# 0      94  91  98  95  85       463
# 1      91  84  91  93  81       440
# 2      99  84  89  82  83       437
# 3      94  84  93  94  81       446
# 4      81  99  85  96  81       442
# ...    ..  ..  ..  ..  ..       ...
# 69995   2  19  22  20  13        76
# 69996  28  26  22   9  29       114
# 69997   9  24  11  28   4        76
# 69998   2   0   5  27   1        35
# 69999  27  21   6  22  20        96
#
# [70000 rows x 6 columns]

# %%
def fnObtained(s1: int, s2: int, s3: int, s4: int, s5: int) -> tuple[int, int, float, str]:

    total: int = 500;

    obtained :int = s1 + s2 + s3 + s4 + s5;

    per : float = obtained / total * 100;

    grade : str = "";

    if per >= 80:
        grade = "A+";
    elif per >= 70:
        grade = "A";
    elif per >= 60:
        grade = "B";
    elif per >= 50:
        grade = "C";
    elif per >= 40:
        grade = "D";
    elif per >= 33:
        grade = "E";
    else:
        grade = "F";

    return total, obtained, per, grade;

df1[["Total", "Obtained", "Percentage", "Grade"]] = df1[["s1", "s2", "s3", "s4", "s5"]].apply(lambda x: fnObtained(* x),
                                                                                             axis=1,
                                                                                             result_type="expand"); # Return Specify Type

df1
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade
# 0      94  91  98  95  85       463    500        92.6    A+
# 1      91  84  91  93  81       440    500        88.0    A+
# 2      99  84  89  82  83       437    500        87.4    A+
# 3      94  84  93  94  81       446    500        89.2    A+
# 4      81  99  85  96  81       442    500        88.4    A+
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...
# 69995   2  19  22  20  13        76    500        15.2     F
# 69996  28  26  22   9  29       114    500        22.8     F
# 69997   9  24  11  28   4        76    500        15.2     F
# 69998   2   0   5  27   1        35    500         7.0     F
# 69999  27  21   6  22  20        96    500        19.2     F
#
# [70000 rows x 9 columns]

# %%
from typing import Dict;

remark : Dict[str, str] = {
    "A+" : "Excellent",
    "A" : "Very Good",
    "B" : "Good",
    "C" : "Fair",
    "D" : "Poor",
    "E" : "Very Poor",
    "F" : "Fail"
};

df1["Remark"] = df1.Grade.map(remark);

df1
# Out:
#        s1  s2  s3  s4  s5  Obtained  Total  Percentage Grade     Remark
# 0      94  91  98  95  85       463    500        92.6    A+  Excellent
# 1      91  84  91  93  81       440    500        88.0    A+  Excellent
# 2      99  84  89  82  83       437    500        87.4    A+  Excellent
# 3      94  84  93  94  81       446    500        89.2    A+  Excellent
# 4      81  99  85  96  81       442    500        88.4    A+  Excellent
# ...    ..  ..  ..  ..  ..       ...    ...         ...   ...        ...
# 69995   2  19  22  20  13        76    500        15.2     F       Fail
# 69996  28  26  22   9  29       114    500        22.8     F       Fail
# 69997   9  24  11  28   4        76    500        15.2     F       Fail
# 69998   2   0   5  27   1        35    500         7.0     F       Fail
# 69999  27  21   6  22  20        96    500        19.2     F       Fail
#
# [70000 rows x 10 columns]

# %% [markdown]
# # **Type Casting On Columns**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int64
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 5.3+ MB

# %%
df1["s1"] = df1["s1"].astype(np.int32);

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int32
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int32(1), int64(6), object(2)
# memory usage: 5.1+ MB

# %%
df1["s1"] = df1["s1"].apply(np.int64);

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   s1          70000 non-null  int64
#  1   s2          70000 non-null  int64
#  2   s3          70000 non-null  int64
#  3   s4          70000 non-null  int64
#  4   s5          70000 non-null  int64
#  5   Obtained    70000 non-null  int64
#  6   Total       70000 non-null  int64
#  7   Percentage  70000 non-null  float64
#  8   Grade       70000 non-null  object
#  9   Remark      70000 non-null  object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 5.3+ MB
